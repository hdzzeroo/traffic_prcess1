# %% [markdown]
# このファイルについて
# - about: 生の検索履歴データから異常なレコードを除去する前処理を行う
# - author: 松永

# %%
import os
from functools import reduce
import datetime as dt
import pandas as pd
import cudf
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### ファイル名などの定数宣言

# %%
ORIGIN_DATA_DIR = '../../Input_original_data'
PROCESSED_DATA_DIR = '../../Input_processed_data'

IC_CSV = f'{PROCESSED_DATA_DIR}/road_master/ic_merged.csv'

ORIGIN_SEARCH_LOG_DIR = lambda month: f'{ORIGIN_DATA_DIR}/search_log/csv{month}'
ORIGIN_SEARCH_LOG_CSV_LIST = lambda date: [
    f'{ORIGIN_SEARCH_LOG_DIR(date[:6])}/DorapuraSearchLog-{date}.csv',
    f'{ORIGIN_SEARCH_LOG_DIR(date[:6])}/ExternalSvrSearchLog-{date}.csv',
    f'{ORIGIN_SEARCH_LOG_DIR(date[:6])}/SwitchSvrSearchLog-{date}.csv'
]

PROCESSED_SEARCH_LOG_DIR = lambda month: f'{PROCESSED_DATA_DIR}/search_records/csv{month}'
PROCESSED_SEARCH_LOG_CSV = lambda date: f'{PROCESSED_SEARCH_LOG_DIR(date[:6])}/record_{date}.csv'

SEARCH_LOG_COLNAME = [
    'date', 'start_code', 'start_name', 'end_code', 'end_name',
    'via1_code', 'via1_name', 'via2_code', 'via2_name', 'via3_code', 'via3_name',
    'spec_day', 'spec_time', 'spec_type', 'order', 'car_type', 'use_nexco', 'use_urban', 'use_local',
    'language'
]

# %% [markdown]
# ### 準備

# %% [markdown]
# #### 時刻操作系関数

# %%
def str2date(date_str, format='%Y%m%d'):
    '''
    文字列形式の日付 => datetime.Dateクラスの日付

    Parameters
    ----------
    date_str: str
    日付
    format: str
    日付文字列の形式

    Returns
    -------
    date: datetime.date
    '''
    date = dt.datetime.strptime(date_str, format).date()
    return date

def str2time(time_str, format='%H:%M'):
    '''
    文字列形式の時刻 => datetime.Timeクラスの時刻
    Parameters
    ----------
    time_str: str
    時刻
    format: str
    時刻文字列の形式

    Returns
    -------
    time: datetime.time
    '''
    time_datetime = dt.datetime.strptime(time_str, format)
    time = time_datetime.time()
    return time

# %% [markdown]
# #### ICコード --> IC名

# %%
df_ic = pd.read_csv(IC_CSV, dtype={'ic_code': str})
code2name = dict(zip(df_ic['ic_code'], df_ic['ic_name']))
name2code = {name: code for code, name in code2name.items()}

# %% [markdown]
# ### オリジナルデータ加工 -> CSV

# %%
def proc_spec_day(x):
    try:
        # dateに変換できるかどうか確認
        return str2date(x, format='%Y/%m/%d')
    except (ValueError, TypeError) as e:
        # print(e, x)
        return
    
def proc_spec_time(x):
    try:
        # dateに変換できるかどうか確認
        return str2time(x)
    except (ValueError, TypeError) as e:
        print(e, x)
        return


def preprocessing(df):
    # ICコードに”E”が含まれている行を除去
    df = df[df['start_code'].str.contains('E') == False]
    df = df[df['end_code'].str.contains('E') == False]

    # マスタデータに含まれないICコードが誤って記録されている行を除去
    df = df[df['start_code'].apply(lambda c: c in code2name)]
    df = df[df['end_code'].apply(lambda c: c in code2name)]

    # マスタデータに含まれないIC名称が誤って指定されている行を除去
    df = df[df['start_name'].apply(lambda n: n in name2code)]
    df = df[df['end_name'].apply(lambda n: n in name2code)]

    # 指定日に異常な日付が入っている行（e.g. 2021/04/31, 210327）を除去
    df['spec_day'] = df['spec_day'].apply(proc_spec_day)
    df = df[df['spec_day'].notna()]

    # 指定時間が”24:00”となっている行の指定日・指定時間を翌日に繰り上げ
    df['spec_day'] = df['spec_day'].mask(df['spec_time'] == '24:00', df['spec_day'] + dt.timedelta(days=1))
    df.replace({'spec_time': {'24:00': '0:00'}}, inplace=True)

    # 指定時間が\"24:12\"のように異常な行を除去
    df = df[df['spec_time'].str[:2] != '24']

    # 「指定言語」列を除去
    df.drop('language', axis=1, inplace=True)

    df.reset_index(drop=True, inplace=True)

    return df

# %%
# test
df = pd.read_csv(ORIGIN_SEARCH_LOG_CSV_LIST('20240801')[0],
          header=0, names=SEARCH_LOG_COLNAME,
          dtype={'start_code': str, 'end_code': str, 'via1_code': str, 'via2_code': str, 'via3_code': str})
df.head()
# Out:
#                   date start_code start_name end_code end_name via1_code  \
# 0  2024/08/01 00:00:00    1050176         滝川  1050191     旭川鷹栖       NaN
# 1  2024/08/01 00:00:00    1110350       三郷中央  5007026       逗子       NaN
# 2  2024/08/01 00:00:00    1120031        千葉北  1020301    宇部ＪＣＴ       NaN
# 3  2024/08/01 00:00:01    5007041         衣笠  6011036      北池袋       NaN
# 4  2024/08/01 00:00:01    1101151        中津川  1910290       高槻       NaN
#
#   via1_name via2_code via2_name via3_code via3_name    spec_day spec_time  \
# 0       NaN       NaN       NaN       NaN       NaN  2024/07/28     09:20
# 1       NaN       NaN       NaN       NaN       NaN  2024/07/31     00:00
# 2       NaN       NaN       NaN       NaN       NaN  2024/08/07     00:00
# 3       NaN       NaN       NaN       NaN       NaN  2024/07/31     13:00
# 4       NaN       NaN       NaN       NaN       NaN  2024/08/05     10:00
#
#    spec_type  order  car_type  use_nexco  use_urban  use_local  language
# 0          1      2         2          1          1          1         0
# 1          1      2         2          1          1          1         0
# 2          1      2         2          1          1          1         0
# 3          1      2         2          1          1          1         0
# 4          1      2         1          1          1          1         0

# %% [markdown]
# ## main

# %%
start_date='20240507'
end_date= '20240831'

DAYS = [d.strftime('%Y%m%d') for d in pd.date_range(start_date, end_date, freq='1D')]

dtypes = {
    'start_code': str, 
    'end_code': str,
    'via1_code': str, 
    'via2_code': str,
    'via3_code': str,
}

for d in DAYS:
    df_day = None
    for csv in ORIGIN_SEARCH_LOG_CSV_LIST(d):
        if not os.path.exists(csv):
            continue

        df = pd.read_csv(csv, header=0, names=SEARCH_LOG_COLNAME, dtype=dtypes)
  
        df = preprocessing(df)
        print(os.path.basename(csv), len(df))

        df_day = pd.concat([df_day, df], ignore_index=True, copy=False)

    print('-'*30, f'[{d}] {len(df_day)} records', '-'*30)

    df_day.to_csv(PROCESSED_SEARCH_LOG_CSV(d), index=False)

print('='*40, 'finished', '='*40)
# Out:
# DorapuraSearchLog-20240507.csv 549405
# ExternalSvrSearchLog-20240507.csv 1413
# SwitchSvrSearchLog-20240507.csv 3210
# ------------------------------ [20240507] 554028 records ------------------------------
# DorapuraSearchLog-20240508.csv 465817
# ExternalSvrSearchLog-20240508.csv 1330
# SwitchSvrSearchLog-20240508.csv 2332
# ------------------------------ [20240508] 469479 records ------------------------------
# DorapuraSearchLog-20240509.csv 483882
# ExternalSvrSearchLog-20240509.csv 1549
# SwitchSvrSearchLog-20240509.csv 2251
# ------------------------------ [20240509] 487682 records ------------------------------
# DorapuraSearchLog-20240510.csv 492643
# ExternalSvrSearchLog-20240510.csv 1248
# SwitchSvrSearchLog-20240510.csv 2033
# ------------------------------ [20240510] 495924 records ------------------------------
# DorapuraSearchLog-20240511.csv 412876
# ExternalSvrSearchLog-20240511.csv 1153
# SwitchSvrSearchLog-20240511.csv 1556
# ------------------------------ [20240511] 415585 records ------------------------------
# DorapuraSearchLog-20240512.csv 395393
# ExternalSvrSearchLog-20240512.csv 991
# SwitchSvrSearchLog-20240512.csv 1605
# ------------------------------ [20240512] 397989 records ------------------------------
# DorapuraSearchLog-20240513.csv 507144
# ExternalSvrSearchLog-20240513.csv 1468
# SwitchSvrSearchLog-20240513.csv 2319
# ------------------------------ [20240513] 510931 records ------------------------------
# DorapuraSearchLog-20240514.csv 465236
# ExternalSvrSearchLog-20240514.csv 1373
# SwitchSvrSearchLog-20240514.csv 1849
# ------------------------------ [20240514] 468458 records ------------------------------
# DorapuraSearchLog-20240515.csv 457567
# ExternalSvrSearchLog-20240515.csv 1294
# SwitchSvrSearchLog-20240515.csv 2254
# ------------------------------ [20240515] 461115 records ------------------------------
# DorapuraSearchLog-20240516.csv 477900
# ExternalSvrSearchLog-20240516.csv 1203
# SwitchSvrSearchLog-20240516.csv 1818
# ------------------------------ [20240516] 480921 records ------------------------------
# DorapuraSearchLog-20240517.csv 477597
# ExternalSvrSearchLog-20240517.csv 1462
# SwitchSvrSearchLog-20240517.csv 6253
# ------------------------------ [20240517] 485312 records ------------------------------
# DorapuraSearchLog-20240518.csv 410242
# ExternalSvrSearchLog-20240518.csv 1452
# SwitchSvrSearchLog-20240518.csv 5832
# ------------------------------ [20240518] 417526 records ------------------------------
# DorapuraSearchLog-20240519.csv 403359
# ExternalSvrSearchLog-20240519.csv 1100
# SwitchSvrSearchLog-20240519.csv 5590
# ------------------------------ [20240519] 410049 records ------------------------------
# DorapuraSearchLog-20240520.csv 519206
# ExternalSvrSearchLog-20240520.csv 1181
# SwitchSvrSearchLog-20240520.csv 7265
# ------------------------------ [20240520] 527652 records ------------------------------
# DorapuraSearchLog-20240521.csv 478671
# ExternalSvrSearchLog-20240521.csv 1342
# SwitchSvrSearchLog-20240521.csv 6103
# ------------------------------ [20240521] 486116 records ------------------------------
# DorapuraSearchLog-20240522.csv 526538
# ExternalSvrSearchLog-20240522.csv 1411
# SwitchSvrSearchLog-20240522.csv 5714
# ------------------------------ [20240522] 533663 records ------------------------------
# DorapuraSearchLog-20240523.csv 522708
# ExternalSvrSearchLog-20240523.csv 1339
# SwitchSvrSearchLog-20240523.csv 6049
# ------------------------------ [20240523] 530096 records ------------------------------
# DorapuraSearchLog-20240524.csv 489313
# ExternalSvrSearchLog-20240524.csv 1406
# SwitchSvrSearchLog-20240524.csv 5178
# ------------------------------ [20240524] 495897 records ------------------------------
# DorapuraSearchLog-20240525.csv 448762
# ExternalSvrSearchLog-20240525.csv 1237
# SwitchSvrSearchLog-20240525.csv 3926
# ------------------------------ [20240525] 453925 records ------------------------------
# DorapuraSearchLog-20240526.csv 434849
# ExternalSvrSearchLog-20240526.csv 1070
# SwitchSvrSearchLog-20240526.csv 4010
# ------------------------------ [20240526] 439929 records ------------------------------
# DorapuraSearchLog-20240527.csv 520507
# ExternalSvrSearchLog-20240527.csv 1249
# SwitchSvrSearchLog-20240527.csv 5302
# ------------------------------ [20240527] 527058 records ------------------------------
# DorapuraSearchLog-20240528.csv 496941
# ExternalSvrSearchLog-20240528.csv 1299
# SwitchSvrSearchLog-20240528.csv 5248
# ------------------------------ [20240528] 503488 records ------------------------------
# DorapuraSearchLog-20240529.csv 462218
# ExternalSvrSearchLog-20240529.csv 1121
# SwitchSvrSearchLog-20240529.csv 4161
# ------------------------------ [20240529] 467500 records ------------------------------
# DorapuraSearchLog-20240530.csv 469519
# ExternalSvrSearchLog-20240530.csv 1135
# SwitchSvrSearchLog-20240530.csv 5082
# ------------------------------ [20240530] 475736 records ------------------------------
# DorapuraSearchLog-20240531.csv 327729
# ExternalSvrSearchLog-20240531.csv 1209
# SwitchSvrSearchLog-20240531.csv 165055
# ------------------------------ [20240531] 493993 records ------------------------------
# DorapuraSearchLog-20240601.csv 408416
# ExternalSvrSearchLog-20240601.csv 1064
# SwitchSvrSearchLog-20240601.csv 19406
# ------------------------------ [20240601] 428886 records ------------------------------
# DorapuraSearchLog-20240602.csv 420702
# ExternalSvrSearchLog-20240602.csv 1008
# SwitchSvrSearchLog-20240602.csv 13798
# ------------------------------ [20240602] 435508 records ------------------------------
# DorapuraSearchLog-20240603.csv 487250
# ExternalSvrSearchLog-20240603.csv 1440
# SwitchSvrSearchLog-20240603.csv 17039
# ------------------------------ [20240603] 505729 records ------------------------------
# DorapuraSearchLog-20240604.csv 407273
# ExternalSvrSearchLog-20240604.csv 1137
# SwitchSvrSearchLog-20240604.csv 13436
# ------------------------------ [20240604] 421846 records ------------------------------
# DorapuraSearchLog-20240605.csv 396013
# ExternalSvrSearchLog-20240605.csv 1209
# SwitchSvrSearchLog-20240605.csv 15835
# ------------------------------ [20240605] 413057 records ------------------------------
# DorapuraSearchLog-20240606.csv 386886
# ExternalSvrSearchLog-20240606.csv 1142
# SwitchSvrSearchLog-20240606.csv 23662
# ------------------------------ [20240606] 411690 records ------------------------------
# DorapuraSearchLog-20240607.csv 424813
# ExternalSvrSearchLog-20240607.csv 1163
# SwitchSvrSearchLog-20240607.csv 11885
# ------------------------------ [20240607] 437861 records ------------------------------
# DorapuraSearchLog-20240608.csv 333985
# ExternalSvrSearchLog-20240608.csv 981
# SwitchSvrSearchLog-20240608.csv 4793
# ------------------------------ [20240608] 339759 records ------------------------------
# DorapuraSearchLog-20240609.csv 340116
# ExternalSvrSearchLog-20240609.csv 1039
# SwitchSvrSearchLog-20240609.csv 5007
# ------------------------------ [20240609] 346162 records ------------------------------
# DorapuraSearchLog-20240610.csv 453798
# ExternalSvrSearchLog-20240610.csv 1065
# SwitchSvrSearchLog-20240610.csv 9115
# ------------------------------ [20240610] 463978 records ------------------------------
# DorapuraSearchLog-20240611.csv 411662
# ExternalSvrSearchLog-20240611.csv 1009
# SwitchSvrSearchLog-20240611.csv 7984
# ------------------------------ [20240611] 420655 records ------------------------------
# DorapuraSearchLog-20240612.csv 387769
# ExternalSvrSearchLog-20240612.csv 1052
# SwitchSvrSearchLog-20240612.csv 7521
# ------------------------------ [20240612] 396342 records ------------------------------
# DorapuraSearchLog-20240613.csv 415047
# ExternalSvrSearchLog-20240613.csv 1170
# SwitchSvrSearchLog-20240613.csv 6214
# ------------------------------ [20240613] 422431 records ------------------------------
# DorapuraSearchLog-20240614.csv 400742
# ExternalSvrSearchLog-20240614.csv 1015
# SwitchSvrSearchLog-20240614.csv 6338
# ------------------------------ [20240614] 408095 records ------------------------------
# DorapuraSearchLog-20240615.csv 318063
# ExternalSvrSearchLog-20240615.csv 1240
# SwitchSvrSearchLog-20240615.csv 3556
# ------------------------------ [20240615] 322859 records ------------------------------
# DorapuraSearchLog-20240616.csv 329417
# ExternalSvrSearchLog-20240616.csv 989
# SwitchSvrSearchLog-20240616.csv 3176
# ------------------------------ [20240616] 333582 records ------------------------------
# DorapuraSearchLog-20240617.csv 376732
# ExternalSvrSearchLog-20240617.csv 1071
# SwitchSvrSearchLog-20240617.csv 5250
# ------------------------------ [20240617] 383053 records ------------------------------
# DorapuraSearchLog-20240618.csv 339454
# ExternalSvrSearchLog-20240618.csv 1405
# SwitchSvrSearchLog-20240618.csv 5104
# ------------------------------ [20240618] 345963 records ------------------------------
# DorapuraSearchLog-20240619.csv 352217
# ExternalSvrSearchLog-20240619.csv 1195
# SwitchSvrSearchLog-20240619.csv 3950
# ------------------------------ [20240619] 357362 records ------------------------------
# DorapuraSearchLog-20240620.csv 340729
# ExternalSvrSearchLog-20240620.csv 1103
# SwitchSvrSearchLog-20240620.csv 4071
# ------------------------------ [20240620] 345903 records ------------------------------
# DorapuraSearchLog-20240621.csv 392687
# ExternalSvrSearchLog-20240621.csv 1248
# SwitchSvrSearchLog-20240621.csv 4348
# ------------------------------ [20240621] 398283 records ------------------------------
# DorapuraSearchLog-20240622.csv 313664
# ExternalSvrSearchLog-20240622.csv 962
# SwitchSvrSearchLog-20240622.csv 2656
# ------------------------------ [20240622] 317282 records ------------------------------
# DorapuraSearchLog-20240623.csv 292919
# ExternalSvrSearchLog-20240623.csv 1095
# SwitchSvrSearchLog-20240623.csv 3032
# ------------------------------ [20240623] 297046 records ------------------------------
# DorapuraSearchLog-20240624.csv 316998
# ExternalSvrSearchLog-20240624.csv 966
# SwitchSvrSearchLog-20240624.csv 3686
# ------------------------------ [20240624] 321650 records ------------------------------
# DorapuraSearchLog-20240625.csv 254162
# ExternalSvrSearchLog-20240625.csv 1184
# SwitchSvrSearchLog-20240625.csv 4277
# ------------------------------ [20240625] 259623 records ------------------------------
# DorapuraSearchLog-20240626.csv 248520
# ExternalSvrSearchLog-20240626.csv 1015
# SwitchSvrSearchLog-20240626.csv 4033
# ------------------------------ [20240626] 253568 records ------------------------------
# DorapuraSearchLog-20240627.csv 269852
# ExternalSvrSearchLog-20240627.csv 988
# SwitchSvrSearchLog-20240627.csv 2375
# ------------------------------ [20240627] 273215 records ------------------------------
# DorapuraSearchLog-20240628.csv 373949
# ExternalSvrSearchLog-20240628.csv 1024
# SwitchSvrSearchLog-20240628.csv 3079
# ------------------------------ [20240628] 378052 records ------------------------------
# DorapuraSearchLog-20240629.csv 317968
# ExternalSvrSearchLog-20240629.csv 949
# SwitchSvrSearchLog-20240629.csv 1805
# ------------------------------ [20240629] 320722 records ------------------------------
# DorapuraSearchLog-20240630.csv 325983
# ExternalSvrSearchLog-20240630.csv 1147
# SwitchSvrSearchLog-20240630.csv 2046
# ------------------------------ [20240630] 329176 records ------------------------------
# DorapuraSearchLog-20240701.csv 419393
# ExternalSvrSearchLog-20240701.csv 1180
# SwitchSvrSearchLog-20240701.csv 2775
# ------------------------------ [20240701] 423348 records ------------------------------
# DorapuraSearchLog-20240702.csv 390929
# ExternalSvrSearchLog-20240702.csv 948
# SwitchSvrSearchLog-20240702.csv 3070
# ------------------------------ [20240702] 394947 records ------------------------------
# DorapuraSearchLog-20240703.csv 390503
# ExternalSvrSearchLog-20240703.csv 1221
# SwitchSvrSearchLog-20240703.csv 2413
# ------------------------------ [20240703] 394137 records ------------------------------
# DorapuraSearchLog-20240704.csv 379477
# ExternalSvrSearchLog-20240704.csv 1049
# SwitchSvrSearchLog-20240704.csv 2397
# ------------------------------ [20240704] 382923 records ------------------------------
# DorapuraSearchLog-20240705.csv 395699
# ExternalSvrSearchLog-20240705.csv 1063
# SwitchSvrSearchLog-20240705.csv 2847
# ------------------------------ [20240705] 399609 records ------------------------------
# DorapuraSearchLog-20240706.csv 329955
# ExternalSvrSearchLog-20240706.csv 1076
# SwitchSvrSearchLog-20240706.csv 2708
# ------------------------------ [20240706] 333739 records ------------------------------
# DorapuraSearchLog-20240707.csv 318325
# ExternalSvrSearchLog-20240707.csv 1050
# SwitchSvrSearchLog-20240707.csv 2922
# ------------------------------ [20240707] 322297 records ------------------------------
# DorapuraSearchLog-20240708.csv 423194
# ExternalSvrSearchLog-20240708.csv 1052
# SwitchSvrSearchLog-20240708.csv 4121
# ------------------------------ [20240708] 428367 records ------------------------------
# DorapuraSearchLog-20240709.csv 413175
# ExternalSvrSearchLog-20240709.csv 1222
# SwitchSvrSearchLog-20240709.csv 4294
# ------------------------------ [20240709] 418691 records ------------------------------
# DorapuraSearchLog-20240710.csv 409384
# ExternalSvrSearchLog-20240710.csv 1327
# SwitchSvrSearchLog-20240710.csv 3722
# ------------------------------ [20240710] 414433 records ------------------------------
# DorapuraSearchLog-20240711.csv 417244
# ExternalSvrSearchLog-20240711.csv 1475
# SwitchSvrSearchLog-20240711.csv 3608
# ------------------------------ [20240711] 422327 records ------------------------------
# DorapuraSearchLog-20240712.csv 430280
# ExternalSvrSearchLog-20240712.csv 1590
# SwitchSvrSearchLog-20240712.csv 3261
# ------------------------------ [20240712] 435131 records ------------------------------
# DorapuraSearchLog-20240713.csv 360316
# ExternalSvrSearchLog-20240713.csv 1830
# SwitchSvrSearchLog-20240713.csv 2778
# ------------------------------ [20240713] 364924 records ------------------------------
# DorapuraSearchLog-20240714.csv 335331
# ExternalSvrSearchLog-20240714.csv 1198
# SwitchSvrSearchLog-20240714.csv 3030
# ------------------------------ [20240714] 339559 records ------------------------------
# DorapuraSearchLog-20240715.csv 370037
# ExternalSvrSearchLog-20240715.csv 1321
# SwitchSvrSearchLog-20240715.csv 2789
# ------------------------------ [20240715] 374147 records ------------------------------
# DorapuraSearchLog-20240716.csv 427315
# ExternalSvrSearchLog-20240716.csv 1407
# SwitchSvrSearchLog-20240716.csv 2929
# ------------------------------ [20240716] 431651 records ------------------------------
# DorapuraSearchLog-20240717.csv 384154
# ExternalSvrSearchLog-20240717.csv 1233
# SwitchSvrSearchLog-20240717.csv 3027
# ------------------------------ [20240717] 388414 records ------------------------------
# DorapuraSearchLog-20240718.csv 392675
# ExternalSvrSearchLog-20240718.csv 1487
# SwitchSvrSearchLog-20240718.csv 2274
# ------------------------------ [20240718] 396436 records ------------------------------
# DorapuraSearchLog-20240719.csv 399499
# ExternalSvrSearchLog-20240719.csv 1236
# SwitchSvrSearchLog-20240719.csv 2061
# ------------------------------ [20240719] 402796 records ------------------------------
# DorapuraSearchLog-20240720.csv 333625
# ExternalSvrSearchLog-20240720.csv 1150
# SwitchSvrSearchLog-20240720.csv 2537
# ------------------------------ [20240720] 337312 records ------------------------------
# DorapuraSearchLog-20240721.csv 319284
# ExternalSvrSearchLog-20240721.csv 1024
# SwitchSvrSearchLog-20240721.csv 1546
# ------------------------------ [20240721] 321854 records ------------------------------
# DorapuraSearchLog-20240722.csv 416015
# ExternalSvrSearchLog-20240722.csv 893
# SwitchSvrSearchLog-20240722.csv 1824
# ------------------------------ [20240722] 418732 records ------------------------------
# DorapuraSearchLog-20240723.csv 378214
# ExternalSvrSearchLog-20240723.csv 1290
# SwitchSvrSearchLog-20240723.csv 1579
# ------------------------------ [20240723] 381083 records ------------------------------
# DorapuraSearchLog-20240724.csv 392409
# ExternalSvrSearchLog-20240724.csv 1239
# SwitchSvrSearchLog-20240724.csv 1599
# ------------------------------ [20240724] 395247 records ------------------------------
# DorapuraSearchLog-20240725.csv 382028
# ExternalSvrSearchLog-20240725.csv 1539
# SwitchSvrSearchLog-20240725.csv 1470
# ------------------------------ [20240725] 385037 records ------------------------------
# DorapuraSearchLog-20240726.csv 428035
# ExternalSvrSearchLog-20240726.csv 1573
# SwitchSvrSearchLog-20240726.csv 2164
# ------------------------------ [20240726] 431772 records ------------------------------
# DorapuraSearchLog-20240727.csv 346083
# ExternalSvrSearchLog-20240727.csv 1337
# SwitchSvrSearchLog-20240727.csv 1301
# ------------------------------ [20240727] 348721 records ------------------------------
# DorapuraSearchLog-20240728.csv 353465
# ExternalSvrSearchLog-20240728.csv 1097
# SwitchSvrSearchLog-20240728.csv 1165
# ------------------------------ [20240728] 355727 records ------------------------------
# DorapuraSearchLog-20240729.csv 461200
# ExternalSvrSearchLog-20240729.csv 1334
# SwitchSvrSearchLog-20240729.csv 1672
# ------------------------------ [20240729] 464206 records ------------------------------
# DorapuraSearchLog-20240730.csv 445028
# ExternalSvrSearchLog-20240730.csv 1462
# SwitchSvrSearchLog-20240730.csv 1843
# ------------------------------ [20240730] 448333 records ------------------------------
# DorapuraSearchLog-20240731.csv 438798
# ExternalSvrSearchLog-20240731.csv 1372
# SwitchSvrSearchLog-20240731.csv 2158
# ------------------------------ [20240731] 442328 records ------------------------------
# DorapuraSearchLog-20240801.csv 439009
# ExternalSvrSearchLog-20240801.csv 1267
# SwitchSvrSearchLog-20240801.csv 1704
# ------------------------------ [20240801] 441980 records ------------------------------
# DorapuraSearchLog-20240802.csv 453758
# ExternalSvrSearchLog-20240802.csv 1412
# SwitchSvrSearchLog-20240802.csv 1592
# ------------------------------ [20240802] 456762 records ------------------------------
# DorapuraSearchLog-20240803.csv 396393
# ExternalSvrSearchLog-20240803.csv 1393
# SwitchSvrSearchLog-20240803.csv 1255
# ------------------------------ [20240803] 399041 records ------------------------------
# DorapuraSearchLog-20240804.csv 413844
# ExternalSvrSearchLog-20240804.csv 1343
# SwitchSvrSearchLog-20240804.csv 1441
# ------------------------------ [20240804] 416628 records ------------------------------
# DorapuraSearchLog-20240805.csv 507491
# ExternalSvrSearchLog-20240805.csv 1547
# SwitchSvrSearchLog-20240805.csv 1532
# ------------------------------ [20240805] 510570 records ------------------------------
# DorapuraSearchLog-20240806.csv 481098
# ExternalSvrSearchLog-20240806.csv 1733
# SwitchSvrSearchLog-20240806.csv 1511
# ------------------------------ [20240806] 484342 records ------------------------------
# DorapuraSearchLog-20240807.csv 461899
# ExternalSvrSearchLog-20240807.csv 1734
# SwitchSvrSearchLog-20240807.csv 1453
# ------------------------------ [20240807] 465086 records ------------------------------
# DorapuraSearchLog-20240808.csv 450059
# ExternalSvrSearchLog-20240808.csv 1902
# SwitchSvrSearchLog-20240808.csv 1517
# ------------------------------ [20240808] 453478 records ------------------------------
# DorapuraSearchLog-20240809.csv 555810
# ExternalSvrSearchLog-20240809.csv 3737
# SwitchSvrSearchLog-20240809.csv 1926
# ------------------------------ [20240809] 561473 records ------------------------------
# DorapuraSearchLog-20240810.csv 523208
# ExternalSvrSearchLog-20240810.csv 3750
# SwitchSvrSearchLog-20240810.csv 1400
# ------------------------------ [20240810] 528358 records ------------------------------
# DorapuraSearchLog-20240811.csv 493087
# ExternalSvrSearchLog-20240811.csv 2878
# SwitchSvrSearchLog-20240811.csv 1391
# ------------------------------ [20240811] 497356 records ------------------------------
# DorapuraSearchLog-20240812.csv 509183
# ExternalSvrSearchLog-20240812.csv 3114
# SwitchSvrSearchLog-20240812.csv 1196
# ------------------------------ [20240812] 513493 records ------------------------------
# DorapuraSearchLog-20240813.csv 515408
# ExternalSvrSearchLog-20240813.csv 2904
# SwitchSvrSearchLog-20240813.csv 1176
# ------------------------------ [20240813] 519488 records ------------------------------
# DorapuraSearchLog-20240814.csv 462052
# ExternalSvrSearchLog-20240814.csv 2904
# SwitchSvrSearchLog-20240814.csv 1331
# ------------------------------ [20240814] 466287 records ------------------------------
# DorapuraSearchLog-20240815.csv 459330
# ExternalSvrSearchLog-20240815.csv 3546
# SwitchSvrSearchLog-20240815.csv 1430
# ------------------------------ [20240815] 464306 records ------------------------------
# DorapuraSearchLog-20240816.csv 489726
# ExternalSvrSearchLog-20240816.csv 2900
# SwitchSvrSearchLog-20240816.csv 1519
# ------------------------------ [20240816] 494145 records ------------------------------
# DorapuraSearchLog-20240817.csv 452293
# ExternalSvrSearchLog-20240817.csv 2817
# SwitchSvrSearchLog-20240817.csv 1281
# ------------------------------ [20240817] 456391 records ------------------------------
# DorapuraSearchLog-20240818.csv 419300
# ExternalSvrSearchLog-20240818.csv 1764
# SwitchSvrSearchLog-20240818.csv 1306
# ------------------------------ [20240818] 422370 records ------------------------------
# DorapuraSearchLog-20240819.csv 498010
# ExternalSvrSearchLog-20240819.csv 1521
# SwitchSvrSearchLog-20240819.csv 1473
# ------------------------------ [20240819] 501004 records ------------------------------
# DorapuraSearchLog-20240820.csv 474019
# ExternalSvrSearchLog-20240820.csv 1548
# SwitchSvrSearchLog-20240820.csv 1667
# ------------------------------ [20240820] 477234 records ------------------------------
# DorapuraSearchLog-20240821.csv 458576
# ExternalSvrSearchLog-20240821.csv 1308
# SwitchSvrSearchLog-20240821.csv 1627
# ------------------------------ [20240821] 461511 records ------------------------------
# DorapuraSearchLog-20240822.csv 453790
# ExternalSvrSearchLog-20240822.csv 1309
# SwitchSvrSearchLog-20240822.csv 1608
# ------------------------------ [20240822] 456707 records ------------------------------
# DorapuraSearchLog-20240823.csv 458923
# ExternalSvrSearchLog-20240823.csv 1652
# SwitchSvrSearchLog-20240823.csv 65723
# ------------------------------ [20240823] 526298 records ------------------------------
# DorapuraSearchLog-20240824.csv 362040
# ExternalSvrSearchLog-20240824.csv 1714
# SwitchSvrSearchLog-20240824.csv 68494
# ------------------------------ [20240824] 432248 records ------------------------------
# DorapuraSearchLog-20240825.csv 360365
# ExternalSvrSearchLog-20240825.csv 1251
# SwitchSvrSearchLog-20240825.csv 70905
# ------------------------------ [20240825] 432521 records ------------------------------
# DorapuraSearchLog-20240826.csv 444517
# ExternalSvrSearchLog-20240826.csv 1466
# SwitchSvrSearchLog-20240826.csv 69620
# ------------------------------ [20240826] 515603 records ------------------------------
# DorapuraSearchLog-20240827.csv 406924
# ExternalSvrSearchLog-20240827.csv 1467
# SwitchSvrSearchLog-20240827.csv 50534
# ------------------------------ [20240827] 458925 records ------------------------------
# DorapuraSearchLog-20240828.csv 409124
# ExternalSvrSearchLog-20240828.csv 2401
# SwitchSvrSearchLog-20240828.csv 1821
# ------------------------------ [20240828] 413346 records ------------------------------
# DorapuraSearchLog-20240829.csv 398220
# ExternalSvrSearchLog-20240829.csv 2310
# SwitchSvrSearchLog-20240829.csv 1776
# ------------------------------ [20240829] 402306 records ------------------------------
# DorapuraSearchLog-20240830.csv 430558
# ExternalSvrSearchLog-20240830.csv 3915
# SwitchSvrSearchLog-20240830.csv 1776
# ------------------------------ [20240830] 436249 records ------------------------------
# DorapuraSearchLog-20240831.csv 386042
# ExternalSvrSearchLog-20240831.csv 2261
# SwitchSvrSearchLog-20240831.csv 1488
# ------------------------------ [20240831] 389791 records ------------------------------
# ======================================== finished ========================================
