# %% [markdown]
# # このファイルについて
# トラカンデータの期間を分割・結合する

# %%
import pandas as pd

# %% [markdown]
# 期間のとり方
# - 2021/04/01 〜 2022/03/31
# - 2022/04/01 〜 2023/03/31
# - 2023/04/01 〜 2023/09/30
# - 2023/10/01 ~ 2024/03/31（推論補助用）
# - 2024/04/01 ~ 2024/05/06（最終評価用）

# %%
# PREFIX = ''
PREFIX = 'merged_1h_'

TARGET_ROAD = 'kannetsu'
# TARGET_ROAD = 'touhoku'

# %%
period1 = '20231001-20240331'
period2 = '20240401-20240506'

# %% [markdown]
# ## データを読み込む

# %%
dtype = {'start_code': 'category', 'end_code': 'category'}

df1 = pd.read_csv(f'./traffic/{PREFIX + TARGET_ROAD}_{period1}_2KP.csv', dtype=dtype)
df2 = pd.read_csv(f'./traffic/{PREFIX + TARGET_ROAD}_{period2}_2KP.csv', dtype=dtype)

# %%
df1.datetime = pd.to_datetime(df1.datetime)
df2.datetime = pd.to_datetime(df2.datetime)

# %%
df1.head(3)
# Out:
#              datetime start_name end_name start_code end_code  \
# 0 2023-10-01 00:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 1 2023-10-01 01:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 2 2023-10-01 02:00:00      大泉ＪＣＴ       所沢    1110210  1800006
#
#    start_pref_code  end_pref_code  start_lat   end_lat   start_lng  ...    KP  \
# 0               13             11   35.75582  35.80615  139.601514  ...  2.48
# 1               13             11   35.75582  35.80615  139.601514  ...  2.48
# 2               13             11   35.75582  35.80615  139.601514  ...  2.48
#
#    start_KP  end_KP  direction  limit_speed   OCC  allCars      speed  \
# 0       0.8     9.4       down        100.0  2.00    633.0  96.380126
# 1       0.8     9.4       down        100.0  1.25    442.0  95.986456
# 2       0.8     9.4       down        100.0  1.00    332.0  96.402402
#
#    search_specified  search_unspecified
# 0                77              6469.0
# 1                12              6469.0
# 2                19              6469.0
#
# [3 rows x 31 columns]

# %%
df1.tail(3)
# Out:
#                   datetime start_name end_name start_code end_code  \
# 606093 2024-03-31 21:00:00         昭和  沼田(関越道)    1800106  1800111
# 606094 2024-03-31 22:00:00         昭和  沼田(関越道)    1800106  1800111
# 606095 2024-03-31 23:00:00         昭和  沼田(関越道)    1800106  1800111
#
#         start_pref_code  end_pref_code  start_lat  end_lat   start_lng  ...  \
# 606093               10             10   36.61077  36.6519  139.070694  ...
# 606094               10             10   36.61077  36.6519  139.070694  ...
# 606095               10             10   36.61077  36.6519  139.070694  ...
#
#             KP  start_KP  end_KP  direction  limit_speed  OCC  allCars  speed  \
# 606093  125.37     120.7   125.9         下り         80.0  NaN      0.0   80.0
# 606094  125.37     120.7   125.9         下り         80.0  NaN      0.0   80.0
# 606095  125.37     120.7   125.9         下り         80.0  NaN      0.0   80.0
#
#         search_specified  search_unspecified
# 606093                17              3148.0
# 606094                 8              3148.0
# 606095                 2              3148.0
#
# [3 rows x 31 columns]

# %%
df2.head(3)
# Out:
#              datetime start_name end_name start_code end_code  \
# 0 2024-04-01 00:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 1 2024-04-01 01:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 2 2024-04-01 02:00:00      大泉ＪＣＴ       所沢    1110210  1800006
#
#    start_pref_code  end_pref_code  start_lat   end_lat   start_lng  ...    KP  \
# 0               13             11   35.75582  35.80615  139.601514  ...  2.48
# 1               13             11   35.75582  35.80615  139.601514  ...  2.48
# 2               13             11   35.75582  35.80615  139.601514  ...  2.48
#
#    start_KP  end_KP  direction  limit_speed       OCC  allCars      speed  \
# 0       0.8     9.4         下り        100.0  2.000000    655.0  96.769817
# 1       0.8     9.4         下り        100.0  1.333333    459.0  97.373913
# 2       0.8     9.4         下り        100.0  1.083333    359.0  94.750000
#
#    search_specified  search_unspecified
# 0                77              4723.0
# 1                37              4723.0
# 2                17              4723.0
#
# [3 rows x 31 columns]

# %%
df2.tail(3)
# Out:
#                   datetime start_name end_name start_code end_code  \
# 119229 2024-05-06 21:00:00         昭和  沼田(関越道)    1800106  1800111
# 119230 2024-05-06 22:00:00         昭和  沼田(関越道)    1800106  1800111
# 119231 2024-05-06 23:00:00         昭和  沼田(関越道)    1800106  1800111
#
#         start_pref_code  end_pref_code  start_lat  end_lat   start_lng  ...  \
# 119229               10             10   36.61077  36.6519  139.070694  ...
# 119230               10             10   36.61077  36.6519  139.070694  ...
# 119231               10             10   36.61077  36.6519  139.070694  ...
#
#             KP  start_KP  end_KP  direction  limit_speed  OCC  allCars  speed  \
# 119229  125.37     120.7   125.9         下り         80.0  NaN      0.0   80.0
# 119230  125.37     120.7   125.9         下り         80.0  NaN      0.0   80.0
# 119231  125.37     120.7   125.9         下り         80.0  NaN      0.0   80.0
#
#         search_specified  search_unspecified
# 119229                19              4021.0
# 119230                 6              4021.0
# 119231                10              4021.0
#
# [3 rows x 31 columns]

# %% [markdown]
# ## データ期間の分割・統合

# %%
df_former = df2.loc[df2.datetime < pd.Timestamp('2024/4/1')]
df_latter = df2.loc[df2.datetime >= pd.Timestamp('2024/4/1')]

# %%
df1_new = pd.concat([df1, df_former], axis=0)
df2_new = pd.concat([df_latter], axis=0)

# %%
# ソート
df1_new = df1_new.sort_values(
    ['start_code', 'end_code', 'KP', 'datetime']
).reset_index(drop=True)

df2_new = df2_new.sort_values(
    ['start_code', 'end_code', 'KP', 'datetime']
).reset_index(drop=True)

# %%
# データフレーム長が一致することを検証
assert len(df1) + len(df2) == len(df1_new) + len(df2_new)

# %%
file1 = f'./traffic/{TARGET_ROAD}_20231001-20240331_2KP.csv'
file2 = f'./traffic/{TARGET_ROAD}_20240401-20240506_2KP.csv'

# %%
# %time df1_new.to_csv(file1, index=False)
# Out:
# CPU times: user 2min 44s, sys: 1.31 s, total: 2min 45s
# Wall time: 2min 45s

# %%
# %time df2_new.to_csv(file2, index=False)
# Out:
# CPU times: user 32.2 s, sys: 255 ms, total: 32.4 s
# Wall time: 32.5 s
