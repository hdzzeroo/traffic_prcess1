# %% [markdown]
# # このファイルについて
# - author: 松永

# %%
import numpy as np
import pandas as pd
import cudf
import missingno as msno
import matplotlib.pyplot as plt

# %%
import cupy
cupy.cuda.Device(1).use()
# Out:
# <CUDA Device 1>

# %%
# 道路名
TARGET_ROAD = 'kannetsu'
# TARGET_ROAD = 'touhoku'

PERIOD = '20230401-20230930'

# 交通量
TRAFFIC_DIR = f'./traffic'
TRAFFIC_CSV = f'{TRAFFIC_DIR}/{TARGET_ROAD}_{PERIOD}_2KP.csv'

# %% [markdown]
# # 欠損値を確認

# %% [markdown]
# ### 長期間にわたって線形補間できない欠損が存在することを確認

# %%
ROADS = ['kannetsu', 'touhoku']
PERIODS = [
    '20210401-20220331',
    '20220401-20230331',
    '20230401-20230930',
]

# %%
def col_interpolate(df: cudf.DataFrame, cols: list, method='linear'):
    """
    dfのcol列内の欠損を区間ごとに線形補間する
    """
    grouped_intp = lambda g: g.reset_index(drop=True).loc[:, cols].interpolate(method=method, axis=0)
    
    df = df.sort_values(['start_code', 'end_code', 'KP', 'datetime']).reset_index(drop=True)
    interpolated = (df.to_pandas()
                    .groupby(['start_code', 'end_code', 'KP'])
                    .apply(grouped_intp)
                    .sort_index()
                    .reset_index())
    
    df_res = df.assign(**{col: interpolated[col] for col in cols})
    return df_res

# %%
for road in ROADS:
    for period in PERIODS:
        print('='*30, road, period, '='*30)

        df_traffic = cudf.from_pandas(
            pd.read_csv(
                f'{TRAFFIC_DIR}/{road}_{period}_2KP.csv', parse_dates=True, index_col='datetime', 
                dtype={'start_code': str, 'end_code': str,}
            )
        ).reset_index()

        df_traffic2 = col_interpolate(df_traffic, cols=['speed', 'OCC', 'allCars'], method='linear')

        # 線形補間ができなかった箇所を列挙
        for g_name, df_g in df_traffic2.loc[df_traffic2.speed.isna()].to_pandas().groupby(['start_name', 'end_name', 'KP']):
            print('-'*20, g_name, '-'*20)
            print('# of null:', df_g.shape[0])
            print('Period:', f'{df_g.datetime.iloc[0]} --> {df_g.datetime.iloc[-1]}')
            print()

        del df_traffic, df_traffic2
# Out:
# ============================== 20210401-20220331 ==============================
# -------------------- ('久喜', '加須', 27.203) --------------------
# # of null: 102936
# Period: 2021-04-01 00:00:00 --> 2022-03-24 09:55:00
#
# -------------------- ('久喜白岡ＪＣＴ', '久喜', 24.999) --------------------
# # of null: 105120
# Period: 2021-04-01 00:00:00 --> 2022-03-31 23:55:00
#
# -------------------- ('佐野藤岡', '佐野ＳＡ', 57.796) --------------------
# # of null: 20004
# Period: 2021-04-01 00:00:00 --> 2021-06-09 10:55:00
#
# -------------------- ('佐野藤岡', '館林', 54.4) --------------------
# # of null: 10524
# Period: 2021-04-01 00:00:00 --> 2021-05-07 12:55:00
#
# -------------------- ('加須', '久喜', 27.203) --------------------
# # of null: 77064
# Period: 2021-04-01 00:00:00 --> 2021-12-24 13:55:00
#
# -------------------- ('加須', '羽生', 36.255) --------------------
# # of null: 10500
# Period: 2021-04-01 00:00:00 --> 2021-05-07 10:55:00
#
# -------------------- ('宇都宮', '鹿沼', 100.261) --------------------
# # of null: 105120
# Period: 2021-04-01 00:00:00 --> 2022-03-31 23:55:00
#
# -------------------- ('栃木都賀ＪＣＴ', '鹿沼', 87.195) --------------------
# # of null: 60360
# Period: 2021-04-01 00:00:00 --> 2021-10-27 13:55:00
#
# -------------------- ('羽生', '加須', 36.245) --------------------
# # of null: 10548
# Period: 2021-04-01 00:00:00 --> 2021-05-07 14:55:00
#
# -------------------- ('館林', '佐野藤岡', 54.34) --------------------
# # of null: 10512
# Period: 2021-04-01 00:00:00 --> 2021-05-07 11:55:00
#
# -------------------- ('鹿沼', '宇都宮', 100.261) --------------------
# # of null: 105120
# Period: 2021-04-01 00:00:00 --> 2022-03-31 23:55:00
#
# ============================== 20220401-20230331 ==============================
# -------------------- ('宇都宮', '鹿沼', 100.261) --------------------
# # of null: 105120
# Period: 2022-04-01 00:00:00 --> 2023-03-31 23:55:00
#
# -------------------- ('栃木都賀ＪＣＴ', '鹿沼', 87.195) --------------------
# # of null: 104376
# Period: 2022-04-01 00:00:00 --> 2023-03-29 09:55:00
#
# -------------------- ('浦和本線', '岩槻', 9.425) --------------------
# # of null: 3012
# Period: 2022-04-01 00:00:00 --> 2022-04-11 10:55:00
#
# -------------------- ('鹿沼', '宇都宮', 100.261) --------------------
# # of null: 105120
# Period: 2022-04-01 00:00:00 --> 2023-03-31 23:55:00
#
# ============================== 20230401-20230930 ==============================
# -------------------- ('宇都宮', '鹿沼', 92.29) --------------------
# # of null: 1740
# Period: 2023-04-01 00:00:00 --> 2023-04-07 00:55:00
#
# -------------------- ('宇都宮', '鹿沼', 96.261) --------------------
# # of null: 3168
# Period: 2023-04-01 00:00:00 --> 2023-04-11 23:55:00
#
# -------------------- ('宇都宮', '鹿沼', 100.261) --------------------
# # of null: 52704
# Period: 2023-04-01 00:00:00 --> 2023-09-30 23:55:00
#
# -------------------- ('岩舟ＪＣＴ', '栃木', 67.494) --------------------
# # of null: 1464
# Period: 2023-04-01 00:00:00 --> 2023-04-06 01:55:00
#
# -------------------- ('栃木', '岩舟ＪＣＴ', 63.995) --------------------
# # of null: 5604
# Period: 2023-04-01 00:00:00 --> 2023-04-20 10:55:00
#
# -------------------- ('栃木', '岩舟ＪＣＴ', 69.404) --------------------
# # of null: 52704
# Period: 2023-04-01 00:00:00 --> 2023-09-30 23:55:00
#
# -------------------- ('鹿沼', '宇都宮', 100.261) --------------------
# # of null: 52704
# Period: 2023-04-01 00:00:00 --> 2023-09-30 23:55:00

# %% [markdown]
# ### 速度の欠損パターンを確認する

# %%
road = 'kannetsu'
# road = 'touhoku'

period = '20230401-20230930'

# %%
df_traffic = pd.read_csv(f'{TRAFFIC_DIR}/{road}_{period}_2KP.csv', dtype={'start_code': str, 'end_code': str,})
df_traffic.head(3)
# Out:
#               datetime start_name end_name start_code end_code  \
# 0  2023-04-01 00:00:00         所沢    大泉ＪＣＴ    1800006  1110210
# 1  2023-04-01 00:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 2  2023-04-01 00:00:00      大泉ＪＣＴ       所沢    1110210  1800006
#
#    start_pref_code  end_pref_code  start_lat   end_lat   start_lng  ...  \
# 0               11             13   35.80615  35.75582  139.535511  ...
# 1               13             11   35.75582  35.80615  139.601514  ...
# 2               13             11   35.75582  35.80615  139.601514  ...
#
#    lane_count  KP_distance    KP  start_KP  end_KP  direction  limit_speed  \
# 0           3          8.6  2.26       9.4     0.8         up        100.0
# 1           3          8.6  2.48       0.8     9.4       down        100.0
# 2           3          8.6  3.90       0.8     9.4       down        100.0
#
#    OCC  allCars  speed
# 0  3.0     91.0   87.0
# 1  3.0     78.0   96.0
# 2  3.0     87.0   84.0
#
# [3 rows x 29 columns]

# %%
def create_na_table(df: pd.DataFrame):
    na_table = df.isna().sum()
    na_percent_table = (df.isna().sum() / len(df_traffic)) * 100
    
    na_table = (pd.concat([na_table, na_percent_table], axis=1)
                .rename(columns={0: '# of null', 1: '% of null'})
                .pipe(lambda _df: _df.loc[_df['# of null'] > 0])
                .sort_values('% of null'))
    return na_table

# %%
create_na_table(df_traffic)
# Out:
#          # of null  % of null
# OCC         295800   3.792214
# allCars     295800   3.792214
# speed       304229   3.900276

# %%
cond1 = df_traffic.speed.isna() & df_traffic.OCC.isna()
cond2 = df_traffic.speed.isna() & df_traffic.OCC.notna()
cond3 = df_traffic.speed.isna() & df_traffic.allCars.notna()

df_tmp1 = df_traffic.loc[cond1]
print(len(df_tmp1))
df_tmp2 = df_traffic.loc[cond2]
print(len(df_tmp2))
df_tmp3 = df_traffic.loc[cond3]
print(len(df_tmp3))
# Out:
# 295800
# 8429
# 8429

# %%
df_tmp2.loc[:, ['OCC', 'allCars']].value_counts().reset_index().rename(columns={0: '# of null (speed)'})
# Out:
#     OCC  allCars  # of null (speed)
# 0   0.0      0.0               8399
# 1   0.0      1.0                 20
# 2   1.0      1.0                  6
# 3   0.0      2.0                  2
# 4   2.0      3.0                  1
# 5  20.0      1.0                  1

# %%
df_tmp3.loc[:, ['OCC', 'allCars']].value_counts().reset_index()
# Out:
#     OCC  allCars     0
# 0   0.0      0.0  8399
# 1   0.0      1.0    20
# 2   1.0      1.0     6
# 3   0.0      2.0     2
# 4   2.0      3.0     1
# 5  20.0      1.0     1

# %%
df_tmp3.loc[:, ['OCC', 'allCars']].value_counts().reset_index()
# Out:
#      OCC  allCars     0
# 0    0.0      0.0  5597
# 1    1.0      1.0     9
# 2    2.0      1.0     8
# 3    0.0      1.0     4
# 4    3.0      2.0     2
# 5    4.0      2.0     2
# 6    5.0      1.0     2
# 7    4.0      1.0     1
# 8    7.0      1.0     1
# 9    9.0      2.0     1
# 10  20.0      1.0     1

# %% [markdown]
# ### 道路別の欠損割合を確認

# %%
road = 'touhoku'

periods = [
    '20210401-20220331',
    '20220401-20230331',
    '20230401-20230930'
]

# %%
df_traffic = pd.DataFrame()

for period in periods:
    print(f'Loading {period}...')
    _df_traffic = pd.read_csv(f'{TRAFFIC_DIR}/{road}_{period}_2KP.csv', dtype={'start_code': str, 'end_code': str,})
    print(f'Finished.')
    df_traffic = pd.concat([df_traffic, _df_traffic])
# Out:
# Loading 20210401-20220331...
# Finished.
# Loading 20220401-20230331...
# Finished.
# Loading 20230401-20230930...
# Finished.

# %%
def create_na_table(df: pd.DataFrame):
    na_table = df.isna().sum()
    na_percent_table = (df.isna().sum() / len(df_traffic)) * 100
    
    na_table = (pd.concat([na_table, na_percent_table], axis=1)
                .rename(columns={0: '# of null', 1: '% of null'})
                .pipe(lambda _df: _df.loc[_df['# of null'] > 0])
                .sort_values('% of null'))
    return na_table

# %% [markdown]
# 5分間での欠損割合

# %%
df_traffic.shape
# Out:
# (38915712, 29)

# %%
create_na_table(df_traffic)
# Out:
#          # of null  % of null
# OCC        1594636   4.097666
# allCars    1594636   4.097666
# speed      1612447   4.143434

# %% [markdown]
# 1時間での欠損割合

# %%
AGG_COLS = ['allCars', 'speed']
AGG_COLS_METHODS = {
    'allCars': 'sum', 
    'accum_speed': 'sum', 
}

# %%
sampling_rate = '1h'

# %%
# 1時間単位でそのままデータを取得すればいいカラム（静的カラム + 1日単位の時間指定なし検索数）
df_static = cudf.from_pandas(
    df_traffic
    .drop(AGG_COLS, axis=1)
    .assign(datetime=pd.to_datetime(df_traffic.datetime))
    .set_index('datetime')
    .groupby(['start_code', 'end_code', 'KP'])
    .apply(lambda g: g.asfreq(sampling_rate))
    .reset_index('datetime')
    .reset_index(drop=True)
)

df_static.head(3)
# Out:
#              datetime start_name end_name start_code end_code  \
# 0 2021-04-01 00:00:00       浦和本線       岩槻    1040013  1040016
# 1 2021-04-01 01:00:00       浦和本線       岩槻    1040013  1040016
# 2 2021-04-01 02:00:00       浦和本線       岩槻    1040013  1040016
#
#    start_pref_code  end_pref_code  start_lat  end_lat   start_lng  ...  hour  \
# 0               11             11   35.89012  35.9347  139.723697  ...     0
# 1               11             11   35.89012  35.9347  139.723697  ...     1
# 2               11             11   35.89012  35.9347  139.723697  ...     2
#
#    minute  lane_count  KP_distance    KP  start_KP  end_KP  direction  \
# 0       0           3          5.7  5.47       4.8    10.5       down
# 1       0           3          5.7  5.47       4.8    10.5       down
# 2       0           3          5.7  5.47       4.8    10.5       down
#
#   limit_speed  OCC
# 0       100.0  2.0
# 1       100.0  2.0
# 2       100.0  2.0
#
# [3 rows x 27 columns]

# %%
df_agg = cudf.from_pandas(
    df_traffic
    .assign(accum_speed=df_traffic['allCars'] * df_traffic['speed'])
    .assign(datetime=pd.to_datetime(df_traffic.datetime))
    .set_index('datetime')
    .groupby(['start_code', 'end_code', 'KP'])
    .apply(lambda g: g.resample(sampling_rate).agg(AGG_COLS_METHODS))
    .reset_index()
)

df_agg.head(3)
# Out:
#   start_code end_code    KP            datetime  allCars  accum_speed
# 0    1040013  1040016  5.47 2021-04-01 00:00:00    558.0      48791.0
# 1    1040013  1040016  5.47 2021-04-01 01:00:00    502.0      43085.0
# 2    1040013  1040016  5.47 2021-04-01 02:00:00    447.0      37685.0

# %%
df = df_static.merge(df_agg, on=['datetime', 'start_code', 'end_code', 'KP'])
df = df.assign(speed=df.accum_speed / (df.allCars + 1)).drop(['accum_speed'], axis=1)

# カラムの順番を揃える
df = df.loc[:, df_traffic.columns]
df.head()
# Out:
#              datetime start_name end_name start_code end_code  \
# 0 2021-12-15 00:00:00       浦和本線       岩槻    1040013  1040016
# 1 2021-12-15 01:00:00       浦和本線       岩槻    1040013  1040016
# 2 2021-12-15 02:00:00       浦和本線       岩槻    1040013  1040016
# 3 2021-12-15 03:00:00       浦和本線       岩槻    1040013  1040016
# 4 2021-12-15 04:00:00       浦和本線       岩槻    1040013  1040016
#
#    start_pref_code  end_pref_code  start_lat  end_lat   start_lng  ...  \
# 0               11             11   35.89012  35.9347  139.723697  ...
# 1               11             11   35.89012  35.9347  139.723697  ...
# 2               11             11   35.89012  35.9347  139.723697  ...
# 3               11             11   35.89012  35.9347  139.723697  ...
# 4               11             11   35.89012  35.9347  139.723697  ...
#
#    lane_count  KP_distance    KP  start_KP  end_KP  direction limit_speed  \
# 0           3          5.7  5.47       4.8    10.5       down       100.0
# 1           3          5.7  5.47       4.8    10.5       down       100.0
# 2           3          5.7  5.47       4.8    10.5       down       100.0
# 3           3          5.7  5.47       4.8    10.5       down       100.0
# 4           3          5.7  5.47       4.8    10.5       down       100.0
#
#    OCC  allCars      speed
# 0  2.0    558.0  85.912343
# 1  2.0    484.0  84.395876
# 2  1.0    465.0  83.912017
# 3  2.0    601.0  82.744186
# 4  3.0    813.0  83.422604
#
# [5 rows x 29 columns]

# %%
# NaNはリサンプリングすると0になる
na_condition = df.speed == 0

# 制限速度で置換
# df.loc[na_condition, 'speed'] = df.loc[na_condition, 'limit_speed']

# %%
n_na = len(df.loc[na_condition])
percent_na = n_na / len(df) * 100

print(f'全体レコード数: {len(df)} | 欠損レコード数: {n_na} | 欠損レコード割合: {percent_na:.3f}[%]')
# Out:
# 全体レコード数: 3242976 | 欠損レコード数: 133282 | 欠損レコード割合: 4.110[%]

# %% [markdown]
# ### 速度の欠損のみを制限速度で埋める
# → resampling後に行う

# %%
# def create_na_table(df: cudf.DataFrame):
#     na_table = df.isna().sum()
#     na_percent_table = (df.isna().sum() / len(df_traffic)) * 100
    
#     na_table = (cudf.concat([na_table, na_percent_table], axis=1)
#                 .rename(columns={0: '# of null', 1: '% of null'})
#                 .pipe(lambda _df: _df.loc[_df['# of null'] > 0])
#                 .sort_values('% of null'))
#     return na_table

# %%
# create_na_table(df_traffic)

# %%
# na_condition = df_traffic.speed.isna()

# # 制限速度で置換
# df_traffic.loc[na_condition, 'speed'] = df_traffic.loc[na_condition, 'limit_speed']

# %%
# create_na_table(df_traffic)

# %%
# %time msno.matrix(df_traffic.to_pandas(), labels=True)
# plt.show()
